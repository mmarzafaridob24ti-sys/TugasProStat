# %% [markdown]
# <a href="https://colab.research.google.com/github/mmarzafaridob24ti-sys/TugasProStat/blob/main/P4_PS_M_MARZAFARIDO_B_3TIC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1b843906-8611-4984-b53a-286462c44eeb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1b843906-8611-4984-b53a-286462c44eeb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
dataraw = pd.read_excel("Latihan Penyajian Data dan Stat Des dg Excel.xlsx")
print(dataraw)
# Out:
#     Unnamed: 0               Unnamed: 1          Unnamed: 2  \
# 0          NaN        Excel Sample Data                 NaN
# 1          NaN                      NaN                 NaN
# 2          NaN  Students Marksheet Data                 NaN
# 3          NaN                      NaN                 NaN
# 4          NaN                      NaN                 NaN
# 5          NaN                       ID                Name
# 6          NaN                   120001            John Doe
# 7          NaN                   120005          Jane Smith
# 8          NaN                   120017     Michael Johnson
# 9          NaN                   120018         Emily Brown
# 10         NaN                   120022     Daniel Martinez
# 11         NaN                   120024        Sarah Wilson
# 12         NaN                   120025        David Garcia
# 13         NaN                   120027         Jessica Lee
# 14         NaN                   120034       Matthew Davis
# ...

# %%
print(dataraw.columns.tolist())
# Out:
# ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7']

# %%
import pandas as pd

dataraw = pd.read_excel("Latihan Penyajian Data dan Stat Des dg Excel.xlsx",header=6,usecols="B:H")

print(dataraw.columns.tolist())
print(dataraw)
# Out:
# ['ID', 'Name', 'Marks in Quiz\n (Out of 100)', 'Mid Term Results (Out of 100)', 'Final Term Resul  (Out of 100)', 'Final Score', 'Grade']
#         ID                Name  Marks in Quiz\n (Out of 100)  \
# 0   120001            John Doe                            85
# 1   120005          Jane Smith                            92
# 2   120017     Michael Johnson                            48
# 3   120018         Emily Brown                            90
# 4   120022     Daniel Martinez                            75
# 5   120024        Sarah Wilson                            88
# 6   120025        David Garcia                            75
# 7   120027         Jessica Lee                            95
# 8   120034       Matthew Davis                            79
# 9   120035  Jennifer Rodriguez                            42
# 10  120036       Andrew Taylor                            53
# 11  120038    Amanda Hernandez                            91
# ...

# %%
datafrq = pd.crosstab(index=dataraw["Grade"], columns="Frekuensi")
print(datafrq)
# Out:
# col_0  Frekuensi
# Grade
# A             12
# AB             7
# B              4
# BC             1
# C              5
# F              1

# %%
datafrq.plot()
# Out:
# <Axes: xlabel='Grade'>

# %%
datafrq.plot(kind='bar')
# Out:
# <Axes: xlabel='Grade'>

# %%
datafrq.plot(kind='pie',y='Frekuensi',autopct='%1.0f%%',legend=False)
# Out:
# <Axes: ylabel='Frekuensi'>

# %%
#Statistika Deskriptif
dataraw["Final Score"] = pd.to_numeric(dataraw["Final Score"], errors='coerce')
dt = dataraw["Final Score"]
stats = dt.describe()
stats['Standard Error'] = dt.sem()
stats['Median'] = dt.median()
stats['Mode'] = dt.mode().iloc[0]
stats['variance'] = dt.var()
stats['range'] = dt.max() - dt.min()
stats['skewness'] = dt.skew()
stats['kurtosis'] = dt.kurtosis()
print(stats)
# Out:
# count              30.000000
# mean               76.221333
# std                13.466585
# min                46.010000
# 25%                68.095000
# 50%                78.800000
# 75%                87.040000
# max                94.030000
# Standard Error      2.458651
# Median             78.800000
# Mode               77.300000
# variance          181.348922
# range              48.020000
# skewness           -0.664190
# kurtosis           -0.527463
# Name: Final Score, dtype: float64
